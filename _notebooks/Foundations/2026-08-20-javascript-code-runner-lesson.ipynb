# %% [markdown]
# ---
# layout: post
# codemirror: true
# comments: True
# title: JavaScript Code Runner Lesson
# description: Practice JavaScript objects, syntax, and loops with interactive code runners.
# permalink: /javascript-code-runner
# ---

# %% [markdown]
# # JavaScript Code Runner Lesson
#
# Run each example, edit the starter code, and use the output to check your changes. These runners work in the browser, so no Java or Python backend is required.
#
# ## Assignment 1: Personalize a Student Record
#
# Change the name, age, and add another property to the object.

# %%
# %%js
#
# // CODE_RUNNER: Personalize Tarun's student record.
#
# const person = {
#     name: 'Tarun',
#     age: 16,
#     favoriteSubject: 'Computer Science'
# };
# console.log(person);

# %% [markdown]
# ## Assignment 2: Practice a Text Message
#
# Run the valid statement first, then change the message and observe the output.

# %%
# %%js
#
# // CODE_RUNNER: Practice changing a text message and run the code.
#
# console.log('Office hours are from 10:00 to 10:30.');

# %% [markdown]
# ## Assignment 3: Practice a Loop
#
# Run the complete loop, then change the start, end, or increment values.

# %%
# %%js
#
# // CODE_RUNNER: Practice changing the loop boundaries.
#
# for (let i = 1; i <= 5; i++) {
#     console.log(i);
# }

# %% [markdown]
# ## What I Learned
#
# I learned how code runners turn JavaScript cells into editable browser exercises. I practiced object properties, syntax debugging, and loop boundaries while using output to check my work.
#
# ## My Unicorn Improvement
#
# My unicorn improvement would be a tiny hint button beside each runner that reveals one clue at a time. It would make debugging feel like following a trail of stars instead of guessing at the whole answer.
